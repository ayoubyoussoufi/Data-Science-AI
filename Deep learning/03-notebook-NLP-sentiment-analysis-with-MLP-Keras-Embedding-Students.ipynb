# %% [markdown]
# # Sentiment analysis with an MLP and vector representation

# %% [markdown]
# # Case Study: Sentiment Analysis
#
# In this lab we use part of the 'Amazon_Unlocked_Mobile.csv' dataset published by Kaggle. The dataset contain the following information:
# * Product Name
# * Brand Name
# * Price
# * Rating
# * Reviews
# * Review Votes
#
# We are mainly interested by the 'Reviews' (X) and by the 'Rating' (y)
#
#
# The goal is to try to predict the 'Rating' after reading the 'Reviews'. I've prepared for you TRAIN and TEST set.
# The work to be done is as follows:
#
# 1. Feature extraction and baseline
#     * read the dataset and understand it
#     * put it in a format so that you can use `CountVectorizer` or`Tf-IDF` to extract the desired features
#     * perform on the desired dates and preprocessing
#     * use one of the classifiers you know to predict the polarity of different sentences
# 1. My first neural network
#     * reuse the features already extracted
#     * proposed a neural network built with Keras
# 1. Hyper-parameter fitting
#     * for the base line: adjust min_df, max_df, ngram, max_features + model's hyper-parameter
#     * for the neural network: adjust batch size, number of layers and number of neuron by layers, use earlystop
# 1. <span style="color:red">Word embedding
#     * stage 1 build a network that uses Keras' embedding which is not language sensitive.
#     * stage 2 build a network that simultaneously uses Keras' embedding and the features extracted in the first weeks.
#     * stage 3 try to use an existing embedding (https://github.com/facebookresearch/MUSE)
#     </span>
#
# **WARNING:** the dataset is voluminous, I can only encourage you to work first on a small part of it and only at the end, when the code is well debugged and that it is necessary to build the "final model", to use the whole dataset.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Read-the-dataset" data-toc-modified-id="Read-the-dataset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Read the dataset</a></span></li><li><span><a href="#Text-normalisation" data-toc-modified-id="Text-normalisation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Text normalisation</a></span></li><li><span><a href="#Approach1---BOW-and-MLP-classifier" data-toc-modified-id="Approach1---BOW-and-MLP-classifier-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Approach1 - BOW and MLP classifier</a></span></li><li><span><a href="#Approach2---Keras-word-embedding-and-MLP-classifier" data-toc-modified-id="Approach2---Keras-word-embedding-and-MLP-classifier-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Approach2 - Keras word embedding and MLP classifier</a></span></li></ul></div>

# %% [markdown]
# ## Read the dataset
#
# Could you find below a proposal. You can complete them.

# %%
#!pip install tensorflow-addons

# %%
import os
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Model
from keras.layers import Input, TextVectorization, Dense, Flatten, Embedding

from sklearn.metrics import f1_score
from sklearn.preprocessing import OneHotEncoder

import tensorflow_addons as tfa
from tensorflow_addons.metrics import F1Score

# %%
TRAIN = pd.read_csv("http://www.i3s.unice.fr/~riveill/dataset/Amazon_Unlocked_Mobile/train.csv.gz")
TEST = pd.read_csv("http://www.i3s.unice.fr/~riveill/dataset/Amazon_Unlocked_Mobile/test.csv.gz")

TRAIN.head()
# Out:
#                                         Product Name Brand Name   Price  \
# 0  Samsung Galaxy Note 4 N910C Unlocked Cellphone...    Samsung  449.99
# 1  BLU Energy X Plus Smartphone - With 4000 mAh S...        BLU  139.00
# 2                   Apple iPhone 6 128GB Silver AT&T      Apple  599.95
# 3  BLU Advance 4.0L Unlocked Smartphone -US GSM -...        BLU   51.99
# 4  Huawei P8 Lite US Version- 5 Unlocked Android ...     Huawei  198.99
#
#    Rating                                            Reviews  Review Votes
# 0       4             I love it!!! I absolutely love it!! 👌👍           0.0
# 1       5  I love the BLU phones! This is my second one t...           4.0
# 2       5                                        Great phone           1.0
# 3       4  Very happy with the performance. The apps work...           2.0
# 4       5                            Easy to use great price           0.0

# %%
''' Construct X_train and y_train '''
X_train = TRAIN['Reviews']
y_train = np.array(TRAIN['Rating']).reshape(-1,1)

X_test = TEST['Reviews']
y_test = np.array(TEST['Rating']).reshape(-1,1)

nb_classes = len(np.unique(y_train))

ohe = OneHotEncoder(sparse=False, handle_unknown='ignore')
y_train_enc = ohe.fit_transform(y_train)
y_test_enc = ohe.fit_transform(y_test)

X_train.shape, y_train_enc.shape, np.unique(y_train)
# Out:
# ((5000,), (5000, 5), array([1, 2, 3, 4, 5], dtype=int64))

# %% [markdown]
# ## Approach1 - BOW and MLP classifier
#
# Using the course companion notebook, build a multi-layer perceptron using a BOW representation of the dataset and evaluate the model.
#
# The dataset being unbalanced the metric will be the f1 score.

# %% [markdown]
# $$TO DO STUDENT$$
# > * Build BOW representation of the train and test set
# > * Fix a value for vocab_size = the maximum number of words to keep, based on word frequency. Only the most common vocab_size-1 words will be kept.

# %%
vocab_size = 8991

tokenize = Tokenizer(num_words=vocab_size, char_level=False)
tokenize.fit_on_texts(X_train) # Remember : you have to fit only on a train part
X_train_enc = tokenize.texts_to_matrix(X_train, mode='tfidf')
X_test_enc = tokenize.texts_to_matrix(X_test, mode='tfidf')

# %%
X_train_enc.shape,X_test_enc.shape
# Out:
# ((5000, 8991), (1000, 8991))

# %% [markdown]
# $$TO DO STUDENT$$
#
# > * Build an MLP and print the model (model.summary())

# %%
# Your code
# define the model
input_ = Input(shape=(vocab_size, ), name="input", dtype=tf.float32)
x = Dense(256, activation="relu", name="hidden")(input_)
output_ = Dense(5, activation='softmax', name="output")(x)
model = Model(input_, output_)
# summarize the model
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 8991)]            0
# _________________________________________________________________
# hidden (Dense)               (None, 256)               2301952
# _________________________________________________________________
# output (Dense)               (None, 5)                 1285
# =================================================================
# Total params: 2,303,237
# Trainable params: 2,303,237
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# $$ TO DO STUDENT $$
# > * Compile the network
# > * Fit the network using EarlyStopping
# > * Babysit your model
# > * Evaluate the network with f1 score

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
import keras.backend as K
def f1_score(y_true, y_pred):
    # Count positive samples.
    c1 = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    c2 = K.sum(K.round(K.clip(y_pred, 0, 1)))
    c3 = K.sum(K.round(K.clip(y_true, 0, 1)))
    # If there are no true samples, fix the F1 score at 0.
    if c3 == 0:
        return 0.0
    # How many selected items are relevant?
    precision = c1 / c2
    # How many relevant items are selected?
    recall = c1 / c3
    # Calculate f1_score
    f1_score = 2 * (precision * recall) / (precision + recall)
    return f1_score

# %%
# compile the model with f1 metrics
# Your code
import tensorflow_addons as tfa
# Compile the model and start training
# I used in metrics before "accuracy" >> check it again
model.compile(loss='categorical_crossentropy', metrics=[f1_score], optimizer='adam')
# Stop training with early stopping with patience of 20
callbacks_list = [EarlyStopping(monitor='val_f1_score', min_delta=0.005, patience=20,
                                verbose=2, mode='min', restore_best_weights=True)
                 ]

# %%
X_train_enc.shape,y_train_enc.shape,X_test_enc.shape, y_test_enc.shape
# Out:
# ((5000, 8991), (5000, 5), (1000, 8991), (1000, 5))

# %%
# fit model using ealy stopping
# Your code
history = model.fit(X_train_enc, y_train_enc, validation_data = (X_test_enc,y_test_enc), callbacks=callbacks_list,
                    batch_size=32, epochs=20)
# Out:
# Epoch 1/20
# 157/157 [==============================] - 3s 19ms/step - loss: 1.0849 - f1_score: nan - val_loss: 0.8763 - val_f1_score: 0.6640
# Epoch 2/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.3963 - f1_score: 0.8634 - val_loss: 0.9836 - val_f1_score: 0.6771
# Epoch 3/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.2158 - f1_score: 0.9371 - val_loss: 1.1156 - val_f1_score: 0.6737
# Epoch 4/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.1462 - f1_score: 0.9554 - val_loss: 1.3094 - val_f1_score: 0.6682
# Epoch 5/20
# 157/157 [==============================] - 3s 17ms/step - loss: 0.1171 - f1_score: 0.9653 - val_loss: 1.4828 - val_f1_score: 0.6670
# Epoch 6/20
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0996 - f1_score: 0.9695 - val_loss: 1.6477 - val_f1_score: 0.6642
# Epoch 7/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0893 - f1_score: 0.9723 - val_loss: 1.7352 - val_f1_score: 0.6567
# Epoch 8/20
# 157/157 [==============================] - 3s 19ms/step - loss: 0.0811 - f1_score: 0.9735 - val_loss: 1.9067 - val_f1_score: 0.6518
# Epoch 9/20
# 157/157 [==============================] - 3s 19ms/step - loss: 0.0741 - f1_score: 0.9760 - val_loss: 2.0258 - val_f1_score: 0.6519
# Epoch 10/20
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0703 - f1_score: 0.9775 - val_loss: 2.2443 - val_f1_score: 0.6574
# Epoch 11/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0661 - f1_score: 0.9772 - val_loss: 2.3016 - val_f1_score: 0.6461
# Epoch 12/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0643 - f1_score: 0.9787 - val_loss: 2.3570 - val_f1_score: 0.6451
# Epoch 13/20
# 157/157 [==============================] - 3s 19ms/step - loss: 0.0612 - f1_score: 0.9799 - val_loss: 2.4728 - val_f1_score: 0.6460
# Epoch 14/20
# 157/157 [==============================] - 3s 20ms/step - loss: 0.0593 - f1_score: 0.9795 - val_loss: 2.5487 - val_f1_score: 0.6344
# Epoch 15/20
# 157/157 [==============================] - 3s 19ms/step - loss: 0.0574 - f1_score: 0.9798 - val_loss: 2.5895 - val_f1_score: 0.6135
# Epoch 16/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0565 - f1_score: 0.9796 - val_loss: 2.7663 - val_f1_score: 0.64570565 - f1_score: 0.97
# Epoch 17/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0548 - f1_score: 0.9812 - val_loss: 2.8459 - val_f1_score: 0.6424
# Epoch 18/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0536 - f1_score: 0.9810 - val_loss: 2.9106 - val_f1_score: 0.6356
# Epoch 19/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0530 - f1_score: 0.9800 - val_loss: 3.0047 - val_f1_score: 0.6378
# Epoch 20/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0510 - f1_score: 0.9823 - val_loss: 3.0607 - val_f1_score: 0.6376

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Plot the learning curves and analyze them
# Babysit your model
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(26,8))

ax1.plot(history.history['loss'], label="loss")
ax1.plot(history.history['val_loss'], label="val_loss")
ax1.legend()
ax2.plot(history.history['f1_score'], label="f1_score")
ax2.plot(history.history['val_f1_score'], label="val_f1_score")
ax2.legend()
plt.show()
# It's possible to plot them very easily using: 
pd.DataFrame(history.history).plot(figsize=(8,5))
# Out:
# <AxesSubplot:>

# %%
# Babysit the model - use you favourite plot
# pd.DataFrame({#'val_loss':history.history['val_loss'],
#               #'loss':history.history['loss'],
#               #'val_f1_score':history.history['val_f1_score'],
#               # 'f1_score':history.history['f1_score'],
#               #'val_accuracy':history.history['val_accuracy'],
#               #'accuracy':history.history['accuracy']
#              }).plot(figsize=(8,5))

# %%
# Evaluate the model with f1 metrics (Tensorflow f1 metrics or sklearn)
# Your code
# Evaluate the model
score = model.evaluate(X_test_enc, y_test_enc)
print('Test loss:', score[0])
print('Test accuracy', score[1])
# Out:
# 32/32 [==============================] - 1s 5ms/step - loss: 3.0607 - f1_score: 0.6376
# Test loss: 3.0606963634490967
# Test accuracy 0.6376453042030334

# %% [markdown]
# ## Approach2 - Keras word embedding and MLP classifier
#
# Using the course companion notebook, build a multi-layer perceptron using an Embedding Keras layer and the same classifier as in approach 1. Evaluate the model.

# %% [markdown]
# $$ TO DO STUDENTS $$
# > * fix the max_lengh of a review (max number of token in a review)
# > * use the same vocab_size as previously
# > * fix the embedding dimension (embed_dim variable)

# %%
# Tokenized the reviews
from nltk.tokenize import word_tokenize
reviews_tokenized = [word_tokenize(review) for review in TRAIN['Reviews']]
a=[len(x) for x in reviews_tokenized] # count number of token per review 
max(a) # print the maximum number of token
# Out:
# 1137

# %%
max_len = 2000   # Sequence length to pad the outputs to.
                # In order to fix it, you have to know the distribution on lengh... see first lab
embed_dim = 50 # embedding dimension

# %% [markdown]
# $$ TO DO STUDENTS $$
#
# >* Create a vectorizer_layer with TextVectorization function
# >* Fit the vectorizer_layer (adapt function

# %%
from keras.layers import Input, TextVectorization, Dense, Flatten, Embedding
# Your code
vectorizer_layer = TextVectorization(max_tokens=max_len, output_sequence_length=max_len)
vectorizer_layer.adapt(X_train)
X_train_vec= vectorizer_layer(X_train)
X_test_vec = vectorizer_layer(X_test)

# %%
X_test_vec.shape, y_test_enc.shape
# Out:
# (TensorShape([1000, 2000]), (1000, 5))

# %% [markdown]
# $$TO DO STUDENT$$
#
# > * Build an MLP and print the model (model.summary())

# %%
# Build word dict
voc = vectorizer_layer.get_vocabulary()
word_index = dict(zip(voc, range(len(voc))))
# word_index

# %%
#If necessary, download glove matrix
# !python -m wget http://nlp.stanford.edu/data/glove.6B.zip
# unzip -q glove.6B.zip

# %%
# Make a dict mapping words (strings) to their NumPy vector representation:
path_to_glove_file = "glove.6B.50d.txt"

embeddings_index = {}
with open(path_to_glove_file,encoding="utf8") as f:
    for line in f:
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, "f", sep=" ")
        embeddings_index[word] = coefs

print("Found %s word vectors." % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
# num_tokens = len(voc) + 2
# embedding_dim = 50
hits = 0
misses = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((max_len, embed_dim))
for word, i in word_index.items():
    print(word, i)
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # Words not found in embedding index will be all-zeros.
        # This includes the representation for "padding" and "OOV"
        embedding_matrix[i] = embedding_vector
        hits += 1
    else:
        misses += 1
print("Converted %d words (%d misses)" % (hits, misses))
# Out:
#  0
# [UNK] 1
# the 2
# i 3
# it 4
# and 5
# phone 6
# a 7
# to 8
# is 9
# this 10
# for 11
# of 12
# with 13
# my 14
# not 15
# in 16
# was 17
# that 18
# but 19
# on 20
# have 21
# you 22
# great 23
# good 24
# as 25
# very 26
# so 27
# its 28
# had 29
# one 30
# be 31
# like 32
# no 33
# all 34
# or 35
# me 36
# if 37
# just 38
# battery 39
# use 40
# has 41
# screen 42
# are 43
# an 44
# would 45
# only 46
# from 47
# at 48
# works 49
# when 50
# can 51
# love 52
# will 53
# get 54
# new 55
# they 56
# work 57
# up 58
# really 59
# time 60
# than 61
# phones 62
# dont 63
# price 64
# product 65
# out 66
# camera 67
# im 68
# am 69
# about 70
# because 71
# buy 72
# well 73
# do 74
# after 75
# bought 76
# sim 77
# card 78
# got 79
# even 80
# more 81
# also 82
# what 83
# other 84
# there 85
# which 86
# back 87
# now 88
# your 89
# iphone 90
# does 91
# any 92
# some 93
# used 94
# nice 95
# excellent 96
# fast 97
# did 98
# better 99
# quality 100
# apps 101
# doesnt 102
# unlocked 103
# then 104
# been 105
# could 106
# came 107
# problem 108
# much 109
# case 110
# best 111
# perfect 112
# by 113
# using 114
# first 115
# android 116
# too 117
# working 118
# 2 119
# still 120
# off 121
# life 122
# want 123
# need 124
# making 667
# lo 668
# impressed 669
# built 670
# today 671
# start 672
# shipped 673
# responsive 674
# player 675
# night 676
# myself 677
# missing 678
# large 679
# friends 680
# extra 681
# es 682
# de 683
# chinese 684
# cases 685
# build 686
# bright 687
# believe 688
# whole 689
# updates 690
# taking 691
# stay 692
# returning 693
# replaced 694
# recommended 695
# otterbox 696
# often 697
# noticed 698
# let 699
# fits 700
# difficult 701
# difference 702
# useless 703
# usage 704
# unfortunately 705
# sucks 706
# speakers 707
# online 708
# normal 709
# lock 710
# hot 711
# en 712
# during 713
# ask 714
# wonderful 715
# wait 716
# supposed 717
# stuck 718
# s4 719
# port 720
# playing 721
# motorola 722
# inside 723
# hour 724
# glass 725
# ear 726
# contacted 727
# considering 728
# connected 729
# coming 730
# check 731
# weight 732
# thinking 733
# stuff 734
# restart 735
# posh 736
# para 737
# operating 738
# numbers 739
# main 740
# happened 741
# everyone 742
# damage 743
# control 744
# activate 745
# xperia 746
# uses 747
# texts 748
# spend 749
# saying 750
# rather 751
# pics 752
# minor 753
# latest 754
# interface 755
# hd 756
# cracked 757
# constantly 758
# con 759
# choice 760
# bueno 761
# bottom 762
# account 763
# 20 764
# web 765
# simply 766
# sending 767
# promised 768
# process 769
# prepaid 770
# plug 771
# paying 772
# past 773
# name 774
# la 775
# ios 776
# friend 777
# contract 778
# carriers 779
# care 780
# bring 781
# twice 782
# turns 783
# thin 784
# surprised 785
# standard 786
# similar 787
# show 788
# seemed 789
# s7 790
# remove 791
# reading 792
# personal 793
# packaging 794
# opened 795
# larger 796
# figure 797
# computer 798
# between 799
# 6s 800
# youll 801
# worse 802
# world 803
# turning 804
# tiny 805
# technology 806
# scratch 807
# reboot 808
# radio 809
# older 810
# menu 811
# means 812
# lots 813
# lollipop 814
# instructions 815
# immediately 816
# giving 817
# functional 818
# damaged 819
# cheaper 820
# cellular 821
# beat 822
# u 823
# stock 824
# spent 825
# space 826
# smartphones 827
# shut 828
# regret 829
# producto 830
# per 831
# mom 832
# mean 833
# manual 834
# kept 835
# hit 836
# hardware 837
# freezes 838
# finger 839
# family 840
# dead 841
# crap 842
# cards 843
# budget 844
# barely 845
# 5s 846
# 15 847
# youtube 848
# write 849
# waiting 850
# sprint 851
# sold 852
# sleek 853
# sensor 854
# repair 855
# ones 856
# near 857
# mail 858
# lumia 859
# list 860
# junk 861
# info 862
# example 863
# colors 864
# avoid 865
# audio 866
# anyway 867
# worried 868
# tech 869
# t 870
# smoothly 871
# single 872
# sharp 873
# research 874
# processor 875
# notice 876
# negative 877
# load 878
# likes 879
# important 880
# idea 881
# happens 882
# given 883
# five 884
# enjoy 885
# english 886
# band 887
# average 888
# alot 889
# slightly 890
# shape 891
# required 892
# ready 893
# protective 894
# protection 895
# okay 896
# multiple 897
# met 898
# mention 899
# matter 900
# learning 901
# language 902
# lack 903
# keeps 904
# install 905
# function 906
# error 907
# early 908
# each 909
# durable 910
# disappointing 911
# died 912
# cricket 913
# basically 914
# above 915
# understand 916
# switching 917
# studio 918
# stop 919
# stolen 920
# sounds 921
# se 922
# scanner 923
# response 924
# press 925
# page 926
# mind 927
# lower 928
# further 1806
# foreign 1807
# forced 1808
# folks 1809
# flawless 1810
# flashlight 1811
# fingerprints 1812
# file 1813
# experiences 1814
# everytime 1815
# ends 1816
# elsewhere 1817
# edges 1818
# dust 1819
# dropping 1820
# drive 1821
# doubt 1822
# door 1823
# disappointment 1824
# dial 1825
# department 1826
# delay 1827
# december 1828
# dark 1829
# dad 1830
# consumer 1831
# companies 1832
# como 1833
# clock 1834
# class 1835
# claimed 1836
# changes 1837
# cel 1838
# careful 1839
# brings 1840
# brick 1841
# breeze 1842
# blank 1843
# became 1844
# beauty 1845
# beats 1846
# bars 1847
# baby 1848
# attention 1849
# aside 1850
# arrival 1851
# areas 1852
# appreciate 1853
# apart 1854
# america 1855
# amazed 1856
# age 1857
# adds 1858
# acting 1859
# across 1860
# accidentally 1861
# 99 1862
# 90 1863
# 80 1864
# 600 1865
# 4gb 1866
# 2gb 1867
# 0 1868
# willing 1869
# wht 1870
# watched 1871
# warm 1872
# vs 1873
# ups 1874
# upgrading 1875
# unresponsive 1876
# uninstall 1877
# unhappy 1878
# tones 1879
# ting 1880
# tiles 1881
# tiene 1882
# thru 1883
# tasks 1884
# surface 1885
# superb 1886
# stick 1887
# stereo 1888
# starter 1889
# stable 1890
# specific 1891
# spare 1892
# solved 1893
# solve 1894
# snap 1895
# smartwatch 1896
# slower 1897
# skype 1898
# sit 1899
# simm 1900
# sign 1901
# shutting 1902
# shopping 1903
# shipment 1904
# safe 1905
# retail 1906
# results 1907
# responds 1908
# request 1909
# report 1910
# rep 1911
# release 1912
# regarding 1913
# recording 1914
# rapido 1915
# problema 1916
# pressing 1917
# practical 1918
# ppi 1919
# poorly 1920
# policy 1921
# plugging 1922
# plans 1923
# perhaps 1924
# performing 1925
# pcs 1926
# payment 1927
# onto 1928
# occasional 1929
# obvious 1930
# noticeable 1931
# netflix 1932
# nervous 1933
# movie 1934
# min 1935
# mic 1936
# metro 1937
# mess 1938
# mb 1939
# marshmallow 1940
# marks 1941
# mark 1942
# locks 1943
# loading 1944
# letters 1945
# lenovo 1946
# leaving 1947
# lcd 1948
# laptop 1949
# languages 1950
# j7 1951
# intended 1952
# instantly 1953
# input 1954
# indicated 1955
# indeed 1956
# impressive 1957
# iii 1958
# heats 1959
# heating 1960
# gripe 1961
# greatest 1962
# glitchy 1963
# format 1964
# fooled 1965
# flaws 1966
# fixes 1967
# firmware 1968
# fill 1969
# feeling 1970
# familiar 1971
# falling 1972
# fall 1973
# fail 1974
# extreme 1975
# exchange 1976
# equipment 1977
# entry 1978
# elegant 1979
# electronic 1980
# e 1981
# driving 1982
# drained 1983
# downloads 1984
# dissapointed 1985
# discovered 1986
# directions 1987
# difficulty 1988
# dialing 1989
# designed 1990
# depending 1991
# defect 1992
# deep 1993
# crashed 1994
# crash 1995
# cracks 1996
# covers 1997
# corners 1998
# corner 1999
# Converted 1981 words (19 misses)

# %%
embedding_layer = Embedding(
    max_len,
    embed_dim,
    embeddings_initializer=tf.keras.initializers.Constant(embedding_matrix),
    trainable=False,
)

# %%
# define the model
input_ = Input(shape=(max_len,), dtype=tf.int32)
x = embedding_layer(input_)
x = Flatten()(x)
output_ = Dense(5, activation='sigmoid')(x)
model1 = Model(input_, output_)
# summarize the model
model1.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 2000)]            0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 2000, 50)          100000
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 100000)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 500005
# =================================================================
# Total params: 600,005
# Trainable params: 500,005
# Non-trainable params: 100,000
# _________________________________________________________________

# %% [markdown]
# $$ TO DO STUDENT $$
# > * Compile the network
# > * Fit the network using EarlyStopping
# > * Babysit your model
# > * Evaluate the network with f1 score

# %%
# compile the model with metrics f1 score
# Your code
# compile the model
model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=[f1_score])

# %%
# fit model using ealy stopping
# Your code
# Stop training with early stopping with patience of 20
callbacks_list = [EarlyStopping(monitor='val_f1_score', min_delta=0.005, patience=20,
                                verbose=2, mode='min', restore_best_weights=True)
                 ]

# %%
history = model1.fit(X_train_vec, y_train_enc, validation_data = (X_test_vec,y_test_enc), callbacks=callbacks_list,
                    batch_size=32, epochs=20)
# Out:
# Epoch 1/20
# 157/157 [==============================] - 3s 17ms/step - loss: 0.4569 - f1_score: 0.5048 - val_loss: 0.4130 - val_f1_score: 0.5565
# Epoch 2/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.3373 - f1_score: 0.6247 - val_loss: 0.3961 - val_f1_score: 0.5615
# Epoch 3/20
# 157/157 [==============================] - 2s 16ms/step - loss: 0.2982 - f1_score: 0.6739 - val_loss: 0.3987 - val_f1_score: 0.5792
# Epoch 4/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.2748 - f1_score: 0.7107 - val_loss: 0.3919 - val_f1_score: 0.5818
# Epoch 5/20
# 157/157 [==============================] - 3s 16ms/step - loss: 0.2582 - f1_score: 0.7329 - val_loss: 0.3963 - val_f1_score: 0.5730
# Epoch 6/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.2452 - f1_score: 0.7530 - val_loss: 0.4006 - val_f1_score: 0.5761
# Epoch 7/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.2343 - f1_score: 0.7654 - val_loss: 0.4043 - val_f1_score: 0.5893
# Epoch 8/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2255 - f1_score: 0.7766 - val_loss: 0.4091 - val_f1_score: 0.5769
# Epoch 9/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2179 - f1_score: 0.7826 - val_loss: 0.4182 - val_f1_score: 0.5823
# Epoch 10/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2108 - f1_score: 0.7901 - val_loss: 0.4202 - val_f1_score: 0.5716
# Epoch 11/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2050 - f1_score: 0.7987 - val_loss: 0.4266 - val_f1_score: 0.5858
# Epoch 12/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.1995 - f1_score: 0.8064 - val_loss: 0.4289 - val_f1_score: 0.5782
# Epoch 13/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.1943 - f1_score: 0.8135 - val_loss: 0.4343 - val_f1_score: 0.5788
# Epoch 14/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.1900 - f1_score: 0.8186 - val_loss: 0.4424 - val_f1_score: 0.5790
# Epoch 15/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.1858 - f1_score: 0.8261 - val_loss: 0.4493 - val_f1_score: 0.5804
# Epoch 16/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.1823 - f1_score: 0.8263 - val_loss: 0.4530 - val_f1_score: 0.5853
# Epoch 17/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.1787 - f1_score: 0.8311 - val_loss: 0.4608 - val_f1_score: 0.5807
# Epoch 18/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.1755 - f1_score: 0.8342 - val_loss: 0.4663 - val_f1_score: 0.5709
# Epoch 19/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.1721 - f1_score: 0.8392 - val_loss: 0.4692 - val_f1_score: 0.5674
# Epoch 20/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.1693 - f1_score: 0.8425 - val_loss: 0.4755 - val_f1_score: 0.5799

# %%
# Babysit the model
pd.DataFrame({'val_loss':history.history['val_loss'],
              'loss':history.history['loss'],
             'val_f1_score':history.history['val_f1_score'],
              'f1_score':history.history['f1_score']}).plot(figsize=(8,5))
# Out:
# <AxesSubplot:>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(26,8))

ax1.plot(history.history['loss'], label="loss")
ax1.plot(history.history['val_loss'], label="val_loss")
ax1.legend()
ax2.plot(history.history['f1_score'], label="f1_score")
ax2.plot(history.history['val_f1_score'], label="val_f1_score")
ax2.legend()
plt.show()
# It's possible to plot them very easily using: 
pd.DataFrame(history.history).plot(figsize=(8,5))
# Out:
# <AxesSubplot:>

# %%
# Evaluate the model
# Your code
# Evaluate the model with f1 metrics (Tensorflow f1 metrics or sklearn)
# Your code
# Evaluate the model
score = model1.evaluate(X_test_vec, y_test_enc)
print('Test loss:', score[0])
print('Test accuracy', score[1])
# Out:
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4755 - f1_score: 0.5799
# Test loss: 0.47546786069869995
# Test accuracy 0.5798975825309753

# %% [markdown]
# ## Approach3 - Word embedding and MLP classifier
#
# Using the course companion notebook, build a multi-layer perceptron using an existing embedding matrix (Word2Vec / Glove or FastText), or on an embedding matrix that you will have built using Gensim.
#
# Use the same constant as a previous steps.
#
# Evaluate the model.

# %%
# Same steps as Keras Embedding
# Your code

# %%
# Build word dict
# Your code

# %%
# Make a dict mapping words (strings) to their NumPy vector representation:
# Your code

# %%
# Prepare embedding matrix
# Your code

# %%
# Define embedding layers
# Your code

# %%
# define the model
# Your code

# %%
# compile the model
# Your code

# %%
# fit model using ealy stopping
# Your code

# %%
# Babysit the model
pd.DataFrame({'val_loss':history.history['val_loss'],
              'loss':history.history['loss'],
             'val_f1_score':history.history['val_f1_score'],
              'f1_score':history.history['f1_score']}).plot(figsize=(8,5))

# %%
# Evaluate the model
# Your code

# %% [markdown]
# ## Approach3 - Word embedding and MLP classifier
#
# Using the course companion notebook, build a multi-layer perceptron using an existing embedding matrix (Word2Vec / Glove or FastText), or on an embedding matrix that you will have built using Gensim.
#
# Use the same constant as a previous steps.
#
# Evaluate the model.

# %%
# Avalaible in your gensim installation... 
# You can also use the train reviews.
corpus_path="/Users/Polytech/anaconda3/Lib/site-packages/gensim/test/test_data/"
# corpus_path="..\Users\Polytech\anaconda3\Lib\site-packages\gensim\test\test_data"
corpus="lee_background.cor"

# %%
# Build gensim model
from gensim.test.utils import datapath
from gensim import utils
import gensim.models

class MyCorpus:
    """An iterator that yields sentences (lists of str)."""

    def __iter__(self):
        for line in open(corpus_path+corpus):
            # assume there's one document per line, tokens separated by whitespace
            yield utils.simple_preprocess(line)
            

sentences = MyCorpus()
model = gensim.models.Word2Vec(sentences=sentences, vector_size=150)

# %%
# Export gensim model
import tempfile

with tempfile.NamedTemporaryFile(prefix='gensim-model-', delete=False) as tmp:
    temporary_filepath = tmp.name
    print(temporary_filepath)
    model.save(temporary_filepath)
    #
    # The model is now safely stored in the filepath.
    # You can copy it to other machines, share it with others, etc.
    #
    # To load a saved model:
    #
    new_model = gensim.models.Word2Vec.load(temporary_filepath)
# Out:
# C:\Users\Polytech\AppData\Local\Temp\gensim-model-e7ld8hgq

# %%
# Load gensim model
new_model = gensim.models.Word2Vec.load(temporary_filepath)

# %%
# Prepare embedding matrix
# Your code
# num_tokens = len(voc) + 2
# embedding_dim = 150
hits = 0
misses = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((max_len, embed_dim))
for word, i in word_index.items():
    try:
        model.wv[word]
        # Words not found in embedding index will be all-zeros.
        # This includes the representation for "padding" and "OOV"
        embedding_matrix[i] = model.wv[word]
        hits += 1
    except :
        misses += 1
print("Converted %d words (%d misses)" % (hits, misses))
# Out:
# Converted 0 words (2000 misses)

# %%
# Define embedding layers
# Your code
embedding_layer = Embedding(
    max_len,
    embed_dim,
    embeddings_initializer=tf.keras.initializers.Constant(embedding_matrix),
    trainable=False,
)

# %%
# define the model
# Your code
# define the model
input_ = Input(shape=(max_len,), dtype=tf.int32)
x = embedding_layer(input_)
x = Flatten()(x)
output_ = Dense(5, activation='sigmoid')(x)
model3 = Model(input_, output_)
# summarize the model
model3.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 2000)]            0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 2000, 50)          100000
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 100000)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 500005
# =================================================================
# Total params: 600,005
# Trainable params: 500,005
# Non-trainable params: 100,000
# _________________________________________________________________

# %%
# compile the model
# Your code
# compile the model with metrics f1 score
# Your code
# compile the model
model3.compile(optimizer='adam', loss='binary_crossentropy', metrics=[f1_score])

# %%
# fit model using ealy stopping
# Your code

# Stop training with early stopping with patience of 20
callbacks_list = [EarlyStopping(monitor='val_f1_score', min_delta=0.005, patience=20,
                                verbose=2, mode='min', restore_best_weights=True)
                 ]

history = model3.fit(X_train_vec, y_train_enc, validation_data = (X_test_vec,y_test_enc), callbacks=callbacks_list,
                    batch_size=32, epochs=20)
# Out:
# Epoch 1/20
# 157/157 [==============================] - 3s 16ms/step - loss: 0.6704 - f1_score: nan - val_loss: 0.6476 - val_f1_score: 0.5547
# Epoch 2/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.6290 - f1_score: 0.5382 - val_loss: 0.6090 - val_f1_score: 0.5547
# Epoch 3/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.5939 - f1_score: 0.5394 - val_loss: 0.5761 - val_f1_score: 0.5547
# Epoch 4/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5642 - f1_score: 0.5382 - val_loss: 0.5485 - val_f1_score: 0.5547
# Epoch 5/20
# 157/157 [==============================] - 3s 16ms/step - loss: 0.5392 - f1_score: 0.5376 - val_loss: 0.5252 - val_f1_score: 0.5547
# Epoch 6/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.5183 - f1_score: 0.5388 - val_loss: 0.5056 - val_f1_score: 0.5547
# Epoch 7/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.5007 - f1_score: 0.5382 - val_loss: 0.4891 - val_f1_score: 0.5547
# Epoch 8/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.4860 - f1_score: 0.5400 - val_loss: 0.4755 - val_f1_score: 0.5547
# Epoch 9/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.4737 - f1_score: 0.5370 - val_loss: 0.4639 - val_f1_score: 0.5547
# Epoch 10/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.4636 - f1_score: 0.5388 - val_loss: 0.4543 - val_f1_score: 0.5547
# Epoch 11/20
# 157/157 [==============================] - 3s 16ms/step - loss: 0.4550 - f1_score: 0.5400 - val_loss: 0.4463 - val_f1_score: 0.5547
# Epoch 12/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.4480 - f1_score: 0.5388 - val_loss: 0.4396 - val_f1_score: 0.5547
# Epoch 13/20
# 157/157 [==============================] - 2s 16ms/step - loss: 0.4421 - f1_score: 0.5388 - val_loss: 0.4340 - val_f1_score: 0.5547
# Epoch 14/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.4372 - f1_score: 0.5376 - val_loss: 0.4294 - val_f1_score: 0.5547
# Epoch 15/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.4332 - f1_score: 0.5382 - val_loss: 0.4255 - val_f1_score: 0.5547
# Epoch 16/20
# 157/157 [==============================] - 2s 16ms/step - loss: 0.4298 - f1_score: 0.5382 - val_loss: 0.4222 - val_f1_score: 0.5547
# Epoch 17/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.4271 - f1_score: 0.5370 - val_loss: 0.4195 - val_f1_score: 0.5547
# Epoch 18/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.4248 - f1_score: 0.5370 - val_loss: 0.4173 - val_f1_score: 0.5547
# Epoch 19/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.4229 - f1_score: 0.5382 - val_loss: 0.4154 - val_f1_score: 0.5547
# Epoch 20/20
# 157/157 [==============================] - 2s 15ms/step - loss: 0.4213 - f1_score: 0.5394 - val_loss: 0.4139 - val_f1_score: 0.5547

# %%
# Babysit the model
pd.DataFrame({'val_loss':history.history['val_loss'],
              'loss':history.history['loss'],
             'val_f1_score':history.history['val_f1_score'],
              'f1_score':history.history['f1_score']}).plot(figsize=(8,5))
# Out:
# <AxesSubplot:>

# %%
# Evaluate the model
# Your code
# Evaluate the model
# Your code
# Evaluate the model with f1 metrics (Tensorflow f1 metrics or sklearn)
# Your code
# Evaluate the model
score = model3.evaluate(X_test_vec, y_test_enc)
print('Test loss:', score[0])
print('Test accuracy', score[1])
# Out:
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4139 - f1_score: 0.5547
# Test loss: 0.4138636589050293
# Test accuracy 0.5546875
